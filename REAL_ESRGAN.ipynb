# %% [markdown]
# <a href="https://colab.research.google.com/github/feyza-inl/Su-Alti-Goruntu-Iyilestirme/blob/main/REAL_ESRGAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install basicsr==1.4.2 --no-deps
# !pip install realesrgan==0.3.0

# basicsr hatasını düzelt
dosya = '/usr/local/lib/python3.12/dist-packages/basicsr/data/degradations.py'
with open(dosya, 'r') as f:
    icerik = f.read()
icerik = icerik.replace(
    'from torchvision.transforms.functional_tensor import rgb_to_grayscale',
    'from torchvision.transforms.functional import rgb_to_grayscale'
)
with open(dosya, 'w') as f:
    f.write(icerik)
print('Hazır!')
# Out:
# Collecting basicsr==1.4.2
#   Downloading basicsr-1.4.2.tar.gz (172 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.5/172.5 kB 6.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: basicsr
#   Building wheel for basicsr (setup.py) ... done
#   Created wheel for basicsr: filename=basicsr-1.4.2-py3-none-any.whl size=214819 sha256=a582c745812879c4ab8ef376f15a8747bdf56324413bfeed8bc63013622ab20b
#   Stored in directory: /root/.cache/pip/wheels/9a/e3/e4/58f29bfabb622dd40b6d9839318ce5bf092062b81ca3aa19ea
# Successfully built basicsr
# Installing collected packages: basicsr
# Successfully installed basicsr-1.4.2
# Collecting realesrgan==0.3.0
#   Downloading realesrgan-0.3.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: basicsr>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from realesrgan==0.3.0) (1.4.2)
# Collecting facexlib>=0.2.5 (from realesrgan==0.3.0)
#   Downloading facexlib-0.3.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting gfpgan>=1.3.5 (from realesrgan==0.3.0)
#   Downloading gfpgan-1.3.8-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from realesrgan==0.3.0) (2.0.2)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (from realesrgan==0.3.0) (4.13.0.92)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from realesrgan==0.3.0) (11.3.0)
# Requirement already satisfied: torch>=1.7 in /usr/local/lib/python3.12/dist-packages (from realesrgan==0.3.0) (2.10.0+cu128)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from realesrgan==0.3.0) (0.25.0+cu128)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from realesrgan==0.3.0) (4.67.3)
# Collecting addict (from basicsr>=1.4.2->realesrgan==0.3.0)
#   Downloading addict-2.4.0-py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: future in /usr/local/lib/python3.12/dist-packages (from basicsr>=1.4.2->realesrgan==0.3.0) (1.0.0)
# Collecting lmdb (from basicsr>=1.4.2->realesrgan==0.3.0)
#   Downloading lmdb-1.7.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (1.4 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from basicsr>=1.4.2->realesrgan==0.3.0) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from basicsr>=1.4.2->realesrgan==0.3.0) (2.32.4)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from basicsr>=1.4.2->realesrgan==0.3.0) (0.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from basicsr>=1.4.2->realesrgan==0.3.0) (1.16.3)
# Collecting tb-nightly (from basicsr>=1.4.2->realesrgan==0.3.0)
#   Downloading tb_nightly-2.21.0a20251023-py3-none-any.whl.metadata (1.9 kB)
# Collecting yapf (from basicsr>=1.4.2->realesrgan==0.3.0)
#   Downloading yapf-0.43.0-py3-none-any.whl.metadata (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 kB 4.0 MB/s eta 0:00:00
# Collecting filterpy (from facexlib>=0.2.5->realesrgan==0.3.0)
#   Downloading filterpy-1.4.5.zip (177 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.0/178.0 kB 8.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numba in /usr/local/lib/python3.12/dist-packages (from facexlib>=0.2.5->realesrgan==0.3.0) (0.60.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.7->realesrgan==0.3.0) (3.24.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7->realesrgan==0.3.0) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.7->realesrgan==0.3.0) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7->realesrgan==0.3.0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7->realesrgan==0.3.0) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7->realesrgan==0.3.0) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7->realesrgan==0.3.0) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7->realesrgan==0.3.0) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7->realesrgan==0.3.0) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7->realesrgan==0.3.0) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7->realesrgan==0.3.0) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7->realesrgan==0.3.0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7->realesrgan==0.3.0) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7->realesrgan==0.3.0) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7->realesrgan==0.3.0) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7->realesrgan==0.3.0) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7->realesrgan==0.3.0) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7->realesrgan==0.3.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7->realesrgan==0.3.0) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7->realesrgan==0.3.0) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7->realesrgan==0.3.0) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7->realesrgan==0.3.0) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7->realesrgan==0.3.0) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7->realesrgan==0.3.0) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=1.7->realesrgan==0.3.0) (1.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.7->realesrgan==0.3.0) (1.3.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from filterpy->facexlib>=0.2.5->realesrgan==0.3.0) (3.10.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.7->realesrgan==0.3.0) (3.0.3)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba->facexlib>=0.2.5->realesrgan==0.3.0) (0.43.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->basicsr>=1.4.2->realesrgan==0.3.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->basicsr>=1.4.2->realesrgan==0.3.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->basicsr>=1.4.2->realesrgan==0.3.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->basicsr>=1.4.2->realesrgan==0.3.0) (2026.2.25)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image->basicsr>=1.4.2->realesrgan==0.3.0) (2.37.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image->basicsr>=1.4.2->realesrgan==0.3.0) (2026.2.24)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.12/dist-packages (from scikit-image->basicsr>=1.4.2->realesrgan==0.3.0) (26.0)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->basicsr>=1.4.2->realesrgan==0.3.0) (0.4)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.12/dist-packages (from tb-nightly->basicsr>=1.4.2->realesrgan==0.3.0) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.12/dist-packages (from tb-nightly->basicsr>=1.4.2->realesrgan==0.3.0) (1.78.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tb-nightly->basicsr>=1.4.2->realesrgan==0.3.0) (3.10.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.12/dist-packages (from tb-nightly->basicsr>=1.4.2->realesrgan==0.3.0) (5.29.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tb-nightly->basicsr>=1.4.2->realesrgan==0.3.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tb-nightly->basicsr>=1.4.2->realesrgan==0.3.0) (3.1.6)
# Requirement already satisfied: platformdirs>=3.5.1 in /usr/local/lib/python3.12/dist-packages (from yapf->basicsr>=1.4.2->realesrgan==0.3.0) (4.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->filterpy->facexlib>=0.2.5->realesrgan==0.3.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->filterpy->facexlib>=0.2.5->realesrgan==0.3.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->filterpy->facexlib>=0.2.5->realesrgan==0.3.0) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->filterpy->facexlib>=0.2.5->realesrgan==0.3.0) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->filterpy->facexlib>=0.2.5->realesrgan==0.3.0) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->filterpy->facexlib>=0.2.5->realesrgan==0.3.0) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->filterpy->facexlib>=0.2.5->realesrgan==0.3.0) (1.17.0)
# Downloading realesrgan-0.3.0-py3-none-any.whl (26 kB)
# Downloading facexlib-0.3.0-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 7.9 MB/s eta 0:00:00
# Downloading gfpgan-1.3.8-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.2/52.2 kB 6.7 MB/s eta 0:00:00
# Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Downloading lmdb-1.7.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (299 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.4/299.4 kB 21.6 MB/s eta 0:00:00
# Downloading tb_nightly-2.21.0a20251023-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 86.2 MB/s eta 0:00:00
# Downloading yapf-0.43.0-py3-none-any.whl (256 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.2/256.2 kB 29.1 MB/s eta 0:00:00
# Building wheels for collected packages: filterpy
#   Building wheel for filterpy (setup.py) ... done
#   Created wheel for filterpy: filename=filterpy-1.4.5-py3-none-any.whl size=110460 sha256=33b46069e0484a4aaa535b6236b821dbe77696e85f7584fd9c403b255d7b789e
#   Stored in directory: /root/.cache/pip/wheels/77/bf/4c/b0c3f4798a0166668752312a67118b27a3cd341e13ac0ae6ee
# Successfully built filterpy
# Installing collected packages: lmdb, addict, yapf, tb-nightly, filterpy, facexlib, gfpgan, realesrgan
# Successfully installed addict-2.4.0 facexlib-0.3.0 filterpy-1.4.5 gfpgan-1.3.8 lmdb-1.7.5 realesrgan-0.3.0 tb-nightly-2.21.0a20251023 yapf-0.43.0
# Hazır!

# %%
# !wget https://github.com/xinntao/Real-ESRGAN/releases/download/v0.1.0/RealESRGAN_x4plus.pth -P /content/weights/

import torch
from realesrgan import RealESRGANer
from basicsr.archs.rrdbnet_arch import RRDBNet

model = RRDBNet(num_in_ch=3, num_out_ch=3, num_feat=64, num_block=23, num_grow_ch=32, scale=4)
upsampler = RealESRGANer(
    scale=4,
    model_path='/content/weights/RealESRGAN_x4plus.pth',
    model=model,
    tile=400,
    tile_pad=10,
    pre_pad=0,
    half=True
)
print('Model hazır!')
# Out:
# --2026-03-04 11:21:11--  https://github.com/xinntao/Real-ESRGAN/releases/download/v0.1.0/RealESRGAN_x4plus.pth
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/387326890/08f0e941-ebb7-48f0-9d6a-73e87b710e7e?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-03-04T11%3A58%3A51Z&rscd=attachment%3B+filename%3DRealESRGAN_x4plus.pth&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-03-04T10%3A58%3A00Z&ske=2026-03-04T11%3A58%3A51Z&sks=b&skv=2018-11-09&sig=jl4j7HYOicLgMcbdWahAuJtgFKtpc9%2BdRwRfOF9%2BQxA%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3MjYyNTA3MSwibmJmIjoxNzcyNjIzMjcxLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.B04YTmt48MhGTWs4Ijk3t_8-1Ub7BZIDjvU9T2TKJcU&response-content-disposition=attachment%3B%20filename%3DRealESRGAN_x4plus.pth&response-content-type=application%2Foctet-stream [following]
# --2026-03-04 11:21:11--  https://release-assets.githubusercontent.com/github-production-release-asset/387326890/08f0e941-ebb7-48f0-9d6a-73e87b710e7e?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-03-04T11%3A58%3A51Z&rscd=attachment%3B+filename%3DRealESRGAN_x4plus.pth&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-03-04T10%3A58%3A00Z&ske=2026-03-04T11%3A58%3A51Z&sks=b&skv=2018-11-09&sig=jl4j7HYOicLgMcbdWahAuJtgFKtpc9%2BdRwRfOF9%2BQxA%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3MjYyNTA3MSwibmJmIjoxNzcyNjIzMjcxLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.B04YTmt48MhGTWs4Ijk3t_8-1Ub7BZIDjvU9T2TKJcU&response-content-disposition=attachment%3B%20filename%3DRealESRGAN_x4plus.pth&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 67040989 (64M) [application/octet-stream]
# Saving to: ‘/content/weights/RealESRGAN_x4plus.pth’
#
# RealESRGAN_x4plus.p 100%[===================>]  63.93M   164MB/s    in 0.4s
#
# 2026-03-04 11:21:12 (164 MB/s) - ‘/content/weights/RealESRGAN_x4plus.pth’ saved [67040989/67040989]
#
# Model hazır!

# %%
import cv2
import os

raw_klasor = '/content/drive/MyDrive/raw-890'
iyilestirilmis_klasor = '/content/drive/MyDrive/iyilestirilmis-890'
os.makedirs(iyilestirilmis_klasor, exist_ok=True)

dosyalar = os.listdir(raw_klasor)
toplam = len(dosyalar)

for i, dosya in enumerate(dosyalar):
    raw_yol = os.path.join(raw_klasor, dosya)
    cikti_yol = os.path.join(iyilestirilmis_klasor, dosya)

    # Zaten işlendiyse atla
    if os.path.exists(cikti_yol):
        continue

    img = cv2.imread(raw_yol, cv2.IMREAD_COLOR)
    if img is None:
        continue

    output, _ = upsampler.enhance(img, outscale=2)
    cv2.imwrite(cikti_yol, output)
    print(f'{i+1}/{toplam} → {dosya}')

print('Tüm görüntüler iyileştirildi!')
# Out:
# 	Tile 1/6
# 	Tile 2/6
# 	Tile 3/6
# 	Tile 4/6
# 	Tile 5/6
# 	Tile 6/6
# 1/890 → 186_img_.png
# 	Tile 1/6
# 	Tile 2/6
# 	Tile 3/6
# 	Tile 4/6
# 	Tile 5/6
# 	Tile 6/6
# 2/890 → 160_img_.png
# 	Tile 1/8
# 	Tile 2/8
# 	Tile 3/8
# 	Tile 4/8
# 	Tile 5/8
# 	Tile 6/8
# 	Tile 7/8
# 	Tile 8/8
# 3/890 → 15704.png
# 	Tile 1/4
# 	Tile 2/4
# 	Tile 3/4
# 	Tile 4/4
# 4/890 → 192_img_.png
# 	Tile 1/4
# 	Tile 2/4
# 	Tile 3/4
# 	Tile 4/4
# 5/890 → 157_img_.png
# 	Tile 1/8
# 	Tile 2/8
# 	Tile 3/8
# 	Tile 4/8
# 	Tile 5/8
# 	Tile 6/8
# 	Tile 7/8
# 	Tile 8/8
# 6/890 → 15544.png
# 	Tile 1/6
# 	Tile 2/6
# 	Tile 3/6
# 	Tile 4/6
# 	Tile 5/6
# 	Tile 6/6
# 7/890 → 19_img_.png
# 	Tile 1/4
# 	Tile 2/4
# 	Tile 3/4
# 	Tile 4/4
# 8/890 → 162_img_.png
# 	Tile 1/4
# 	Tile 2/4
# 	Tile 3/4
# 	Tile 4/4
# 9/890 → 159_img_.png
# 	Tile 1/4
# 	Tile 2/4
# 	Tile 3/4
# 	Tile 4/4
# 10/890 → 155_img_.png
# 	Tile 1/4
# 	Tile 2/4
# 	Tile 3/4
# 	Tile 4/4
# 11/890 → 194_img_.png
# 	Tile 1/4
# 	Tile 2/4
# 	Tile 3/4
# 	Tile 4/4
# 12/890 → 196_img_.png
# 	Tile 1/8
# 	Tile 2/8
# 	Tile 3/8
# 	Tile 4/8
# 	Tile 5/8
# 	Tile 6/8
# 	Tile 7/8
# 	Tile 8/8
# 13/890 → 20.png
# 	Tile 1/2
# 	Tile 2/2
# 14/890 → 200_img_.png
# 	Tile 1/8
# 	Tile 2/8
# 	Tile 3/8
# 	Tile 4/8
# 	Tile 5/8
# 	Tile 6/8
# 	Tile 7/8
# 	Tile 8/8
# 15/890 → 15426.png
# 	Tile 1/8
# 	Tile 2/8
# 	Tile 3/8
# 	Tile 4/8
# 	Tile 5/8
# 	Tile 6/8
# 	Tile 7/8
# 	Tile 8/8
# 16/890 → 1539.png
# 	Tile 1/8
# 	Tile 2/8
# 	Tile 3/8
# 	Tile 4/8
# 	Tile 5/8
# 	Tile 6/8
# 	Tile 7/8
# 	Tile 8/8
# 17/890 → 1573.png
# 	Tile 1/4
# 	Tile 2/4
# 	Tile 3/4
# 	Tile 4/4
# 18/890 → 205_img_.png
# 	Tile 1/4
# 	Tile 2/4
# 	Tile 3/4
# 	Tile 4/4
# 19/890 → 153_img_.png
# 	Tile 1/12
# 	Tile 2/12
# 	Tile 3/12
# 	Tile 4/12
# 	Tile 5/12
# 	Tile 6/12
# 	Tile 7/12
# 	Tile 8/12
# 	Tile 9/12
# 	Tile 10/12
# 	Tile 11/12
# 	Tile 12/12
# 20/890 → 203_img_.png
# 	Tile 1/8
# 	Tile 2/8
# 	Tile 3/8
# 	Tile 4/8
# 	Tile 5/8
# 	Tile 6/8
# 	Tile 7/8
# 	Tile 8/8
# 21/890 → 15418.png
# 	Tile 1/2
# 	Tile 2/2
# 22/890 → 152_img_.png
# 	Tile 1/2
# 	Tile 2/2
# 23/890 → 204_img_.png
# 	Tile 1/4
# 	Tile 2/4
# 	Tile 3/4
# 	Tile 4/4
# 24/890 → 202_img_.png
# 	Tile 1/4
# 	Tile 2/4
# 	Tile 3/4
# 	Tile 4/4
# 25/890 → 188_img_.png
# 	Tile 1/4
# 	Tile 2/4
# 	Tile 3/4
# 	Tile 4/4
# 26/890 → 154_img_.png
# 	Tile 1/4
# 	Tile 2/4
# 	Tile 3/4
# 	Tile 4/4
# 27/890 → 201_img_.png
# 	Tile 1/8
# 	Tile 2/8
# 	Tile 3/8
# 	Tile 4/8
# 	Tile 5/8
# 	Tile 6/8
# 	Tile 7/8
# 	Tile 8/8
# 28/890 → 189_img_.png
# 	Tile 1/4
# 	Tile 2/4
# 	Tile 3/4
# 	Tile 4/4
# 29/890 → 191_img_.png
# 	Tile 1/4
# 	Tile 2/4
# 	Tile 3/4
# 	Tile 4/4
# 30/890 → 151_img_.png
# 	Tile 1/4
# 	Tile 2/4
# 	Tile 3/4
# 	Tile 4/4
# 31/890 → 163_img_.png
# 	Tile 1/4
# 	Tile 2/4
# 	Tile 3/4
# 	Tile 4/4
# 32/890 → 15_img_.png
# 	Tile 1/4
# 	Tile 2/4
# 	Tile 3/4
# 	Tile 4/4
# 33/890 → 199_img_.png
# 	Tile 1/2
# 	Tile 2/2
# 34/890 → 197_img_.png
# 	Tile 1/4
# 	Tile 2/4
# 	Tile 3/4
# 	Tile 4/4
# 35/890 → 198_img_.png
# 	Tile 1/4
# 	Tile 2/4
# 	Tile 3/4
# 	Tile 4/4
# 36/890 → 193_img_.png
# 	Tile 1/4
# 	Tile 2/4
# 	Tile 3/4
# 	Tile 4/4
# 37/890 → 156_img_.png
# 	Tile 1/6
# 	Tile 2/6
# 	Tile 3/6
# 	Tile 4/6
# 	Tile 5/6
# 	Tile 6/6
# 38/890 → 184_img_.png
# 	Tile 1/4
# 	Tile 2/4
# 	Tile 3/4
# 	Tile 4/4
# 39/890 → 161_img_.png
# 	Tile 1/4
# 	Tile 2/4
# 	Tile 3/4
# 	Tile 4/4
# 40/890 → 18_img_.png
# 	Tile 1/8
# 	Tile 2/8
# 	Tile 3/8
# 	Tile 4/8
# 	Tile 5/8
# 	Tile 6/8
# 	Tile 7/8
# 	Tile 8/8
# 41/890 → 1957.png
# 	Tile 1/4
# 	Tile 2/4
# 	Tile 3/4
# 	Tile 4/4
# 42/890 → 190_img_.png
# 	Tile 1/8
# 	Tile 2/8
# 	Tile 3/8
# 	Tile 4/8
# 	Tile 5/8
# 	Tile 6/8
# 	Tile 7/8
# 	Tile 8/8
# 43/890 → 15136.png
# 	Tile 1/4
# 	Tile 2/4
# 	Tile 3/4
# 	Tile 4/4
# 44/890 → 206_img_.png
# 	Tile 1/6
# 	Tile 2/6
# 	Tile 3/6
# 	Tile 4/6
# 	Tile 5/6
# 	Tile 6/6
# 45/890 → 173_img_.png
# 	Tile 1/4
# 	Tile 2/4
# 	Tile 3/4
# 	Tile 4/4
# 46/890 → 179_img_.png
# 	Tile 1/8
# 	Tile 2/8
# 	Tile 3/8
# 	Tile 4/8
# 	Tile 5/8
# 	Tile 6/8
# 	Tile 7/8
# 	Tile 8/8
# 47/890 → 1742.png
# 	Tile 1/4
# 	Tile 2/4
# 	Tile 3/4
# 	Tile 4/4
# 48/890 → 175_img_.png
# 	Tile 1/4
# 	Tile 2/4
# 	Tile 3/4
# 	Tile 4/4
# 49/890 → 174_img_.png
# 	Tile 1/4
# 	Tile 2/4
# 	Tile 3/4
# 	Tile 4/4
# 50/890 → 165_img_.png
# 	Tile 1/4
# 	Tile 2/4
# 	Tile 3/4
# 	Tile 4/4
# 51/890 → 183_img_.png
# 	Tile 1/6
# 	Tile 2/6
# 	Tile 3/6
# 	Tile 4/6
# 	Tile 5/6
# 	Tile 6/6
# 52/890 → 172_img_.png
# 	Tile 1/2
# 	Tile 2/2
# 53/890 → 17_img_.png
# 	Tile 1/4
# 	Tile 2/4
# 	Tile 3/4
# 	Tile 4/4
# 54/890 → 171_img_.png
# 	Tile 1/8
# 	Tile 2/8
# 	Tile 3/8
# 	Tile 4/8
# 	Tile 5/8
# 	Tile 6/8
# 	Tile 7/8
# 	Tile 8/8
# 55/890 → 1660.png
# 	Tile 1/6
# 	Tile 2/6
# 	Tile 3/6
# 	Tile 4/6
# 	Tile 5/6
# 	Tile 6/6
# 56/890 → 182_img_.png
# 	Tile 1/2
# 	Tile 2/2
# 57/890 → 176_img_.png
# 	Tile 1/4
# 	Tile 2/4
# 	Tile 3/4
# 	Tile 4/4
# 58/890 → 16_img_.png
# 	Tile 1/4
# 	Tile 2/4
# 	Tile 3/4
# 	Tile 4/4
# 59/890 → 164_img_.png
# 	Tile 1/6
# 	Tile 2/6
# 	Tile 3/6
# 	Tile 4/6
# 	Tile 5/6
# 	Tile 6/6
# 60/890 → 169_img_.png
# 	Tile 1/4
# 	Tile 2/4
# 	Tile 3/4
# 	Tile 4/4
# 61/890 → 177_img_.png
# 	Tile 1/4
# 	Tile 2/4
# 	Tile 3/4
# 	Tile 4/4
# 62/890 → 170_img_.png
# 	Tile 1/4
# 	Tile 2/4
# 	Tile 3/4
# 	Tile 4/4
# 63/890 → 185_img_.png
# 	Tile 1/12
# 	Tile 2/12
# 	Tile 3/12
# 	Tile 4/12
# 	Tile 5/12
# 	Tile 6/12
# 	Tile 7/12
# 	Tile 8/12
# 	Tile 9/12
# 	Tile 10/12
# 	Tile 11/12
# 	Tile 12/12
# 64/890 → 168_img_.png
# 	Tile 1/4
# 	Tile 2/4
# 	Tile 3/4
# 	Tile 4/4
# 65/890 → 178_img_.png
# 	Tile 1/8
# 	Tile 2/8
# 	Tile 3/8
# 	Tile 4/8
# 	Tile 5/8
# 	Tile 6/8
# 	Tile 7/8
# 	Tile 8/8
# 66/890 → 15113.png
# 	Tile 1/4
# 	Tile 2/4
# 	Tile 3/4
# 	Tile 4/4
# 67/890 → 166_img_.png
# 	Tile 1/4
# 	Tile 2/4
# 	Tile 3/4
# 	Tile 4/4
# 68/890 → 158_img_.png
# 	Tile 1/4
# 	Tile 2/4
# 	Tile 3/4
# 	Tile 4/4
# 69/890 → 180_img_.png
# 	Tile 1/4
# 	Tile 2/4
# 	Tile 3/4
# 	Tile 4/4
# 70/890 → 187_img_.png
# 	Tile 1/8
# 	Tile 2/8
# 	Tile 3/8
# 	Tile 4/8
# 	Tile 5/8
# 	Tile 6/8
# 	Tile 7/8
# 	Tile 8/8
# 71/890 → 15001.png
# 	Tile 1/4
# 	Tile 2/4
# 	Tile 3/4
# 	Tile 4/4
# 72/890 → 137_img_.png
# 	Tile 1/9
# 	Tile 2/9
# 	Tile 3/9
# 	Tile 4/9
# 	Tile 5/9
# 	Tile 6/9
# 	Tile 7/9
# 	Tile 8/9
# 	Tile 9/9
# 73/890 → 143_img_.png
# 	Tile 1/8
# 	Tile 2/8
# 	Tile 3/8
# 	Tile 4/8
# 	Tile 5/8
# 	Tile 6/8
# 	Tile 7/8
# 	Tile 8/8
#
img_.png
# 	Tile 1/2
# 	Tile 2/2
# 183/890 → 518_img_.png
# 	Tile 1/2
# 	Tile 2/2
# 184/890 → 517_img_.png
# 	Tile 1/4
# 	Tile 2/4
# 	Tile 3/4
# 	Tile 4/4
# 185/890 → 519_img_.png
# 	Tile 1/8
# 	Tile 2/8
# 	Tile 3/8
# 	Tile 4/8
# 	Tile 5/8
# 	Tile 6/8
# 	Tile 7/8
# 	Tile 8/8
# 186/890 → 498_img_.png
# 	Tile 1/2
# 	Tile 2/2
# 187/890 → 487_img_.png
# 	Tile 1/4
# 	Tile 2/4
# 	Tile 3/4
# 	Tile 4/4
# 188/890 → 491_img_.png
# 	Tile 1/4
# 	Tile 2/4
# 	Tile 3/4
# 	Tile 4/4
# 189/890 → 496_img_.png
# 	Tile 1/12
# 	Tile 2/12
# 	Tile 3/12
# 	Tile 4/12
# 	Tile 5/12
# 	Tile 6/12
# 	Tile 7/12
# 	Tile 8/12
# 	Tile 9/12
# 	Tile 10/12
# 	Tile 11/12
# 	Tile 12/12
# 190/890 → 507_img_.png
# 	Tile 1/6
# 	Tile 2/6
# 	Tile 3/6
# 	Tile 4/6
# 	Tile 5/6
# 	Tile 6/6
# 191/890 → 524_img_.png
# 	Tile 1/6
# 	Tile 2/6
# 	Tile 3/6
# 	Tile 4/6
# 	Tile 5/6
# 	Tile 6/6
# 192/890 → 511_img_.png
# 	Tile 1/12
# 	Tile 2/12
# 	Tile 3/12
# 	Tile 4/12
# 	Tile 5/12
# 	Tile 6/12
# 	Tile 7/12
# 	Tile 8/12
# 	Tile 9/12
# 	Tile 10/12
# 	Tile 11/12
# 	Tile 12/12
# 193/890 → 49_img_.png
# 	Tile 1/2
# 	Tile 2/2
# 194/890 → 541_img_.png
# 	Tile 1/2
# 	Tile 2/2
# 195/890 → 540_img_.png
# 	Tile 1/4
# 	Tile 2/4
# 	Tile 3/4
# 	Tile 4/4
# 196/890 → 51_img_.png
# 	Tile 1/15
# 	Tile 2/15
# 	Tile 3/15
# 	Tile 4/15
# 	Tile 5/15
# 	Tile 6/15
# 	Tile 7/15
# 	Tile 8/15
# 	Tile 9/15
# 	Tile 10/15
# 	Tile 11/15
# 	Tile 12/15
# 	Tile 13/15
# 	Tile 14/15
# 	Tile 15/15
# 197/890 → 510_img_.png
# 	Tile 1/2
# 	Tile 2/2
# 198/890 → 471_img_.png
# 	Tile 1/12
# 	Tile 2/12
# 	Tile 3/12
# 	Tile 4/12
# 	Tile 5/12
# 	Tile 6/12
# 	Tile 7/12
# 	Tile 8/12
# 	Tile 9/12
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3277/2450927747.py in <cell line: 0>()
#      21         continue
#      22
# ---> 23     output, _ = upsampler.enhance(img, outscale=2)
#      24     cv2.imwrite(cikti_yol, output)
#      25     print(f'{i+1}/{toplam} → {dosya}')
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     122         # pyrefly: ignore [bad-context-manager]
#     123         with ctx_factory():
# --> 124             return func(*args, **kwargs)
#     125
#     126     return decorate_context
#
# /usr/local/lib/python3.12/dist-packages/realesrgan/utils.py in enhance(self, img, outscale, alpha_upsampler)
#     219         self.pre_process(img)
#     220         if self.tile_size > 0:
# --> 221             self.tile_process()
#     222         else:
#     223             self.process()
#
# /usr/local/lib/python3.12/dist-packages/realesrgan/utils.py in tile_process(self)
#     158                 try:
#     159                     with torch.no_grad():
# --> 160                         output_tile = self.model(input_tile)
#     161                 except RuntimeError as error:
#     162                     print('Error', error)
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775         else:
# -> 1776             return self._call_impl(*args, **kwargs)
#    1777
#    1778     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1785                 or _global_backward_pre_hooks or _global_backward_hooks
#    1786                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787             return forward_call(*args, **kwargs)
#    1788
#    1789         result = None
#
# /usr/local/lib/python3.12/dist-packages/basicsr/archs/rrdbnet_arch.py in forward(self, x)
#     111             feat = x
#     112         feat = self.conv_first(feat)
# --> 113         body_feat = self.conv_body(self.body(feat))
#     114         feat = feat + body_feat
#     115         # upsample
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775         else:
# -> 1776             return self._call_impl(*args, **kwargs)
#    1777
#    1778     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1785                 or _global_backward_pre_hooks or _global_backward_hooks
#    1786                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787             return forward_call(*args, **kwargs)
#    1788
#    1789         result = None
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     251         """
#     252         for module in self:
# --> 253             input = module(input)
#     254         return input
#     255
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775         else:
# -> 1776             return self._call_impl(*args, **kwargs)
#    1777
#    1778     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1785                 or _global_backward_pre_hooks or _global_backward_hooks
#    1786                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787             return forward_call(*args, **kwargs)
#    1788
#    1789         result = None
#
# /usr/local/lib/python3.12/dist-packages/basicsr/archs/rrdbnet_arch.py in forward(self, x)
#      59         out = self.rdb1(x)
#      60         out = self.rdb2(out)
# ---> 61         out = self.rdb3(out)
#      62         # Empirically, we use 0.2 to scale the residual for better performance
#      63         return out * 0.2 + x
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775         else:
# -> 1776             return self._call_impl(*args, **kwargs)
#    1777
#    1778     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1785                 or _global_backward_pre_hooks or _global_backward_hooks
#    1786                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787             return forward_call(*args, **kwargs)
#    1788
#    1789         result = None
#
# /usr/local/lib/python3.12/dist-packages/basicsr/archs/rrdbnet_arch.py in forward(self, x)
#      35         x3 = self.lrelu(self.conv3(torch.cat((x, x1, x2), 1)))
#      36         x4 = self.lrelu(self.conv4(torch.cat((x, x1, x2, x3), 1)))
# ---> 37         x5 = self.conv5(torch.cat((x, x1, x2, x3, x4), 1))
#      38         # Empirically, we use 0.2 to scale the residual for better performance
#      39         return x5 * 0.2 + x
#
# KeyboardInterrupt:

# %%
import cv2
import numpy as np
import os
from skimage.metrics import peak_signal_noise_ratio as psnr
from skimage.metrics import structural_similarity as ssim

ref_klasor = '/content/drive/MyDrive/reference-890-extracted/reference-890'
iyilestirilmis_klasor = '/content/drive/MyDrive/iyilestirilmis-890'
raw_klasor = '/content/drive/MyDrive/raw-890'

psnr_raw_listesi = []
ssim_raw_listesi = []
psnr_iyi_listesi = []
ssim_iyi_listesi = []

for dosya in os.listdir(raw_klasor):
    raw_yol = os.path.join(raw_klasor, dosya)
    ref_yol = os.path.join(ref_klasor, dosya)
    iyi_yol = os.path.join(iyilestirilmis_klasor, dosya)

    if not os.path.exists(ref_yol) or not os.path.exists(iyi_yol):
        continue

    raw = cv2.imread(raw_yol)
    ref = cv2.imread(ref_yol)
    iyi = cv2.imread(iyi_yol)

    # Hepsini RAW boyutuna getir
    hedef_boyut = (raw.shape[1], raw.shape[0])
    ref_r = cv2.resize(ref, hedef_boyut)
    iyi_r = cv2.resize(iyi, hedef_boyut)  # İyileştirilmiş de küçültülüyor

    psnr_raw_listesi.append(psnr(ref_r, raw))
    ssim_raw_listesi.append(ssim(ref_r, raw, channel_axis=2))
    psnr_iyi_listesi.append(psnr(ref_r, iyi_r))
    ssim_iyi_listesi.append(ssim(ref_r, iyi_r, channel_axis=2))

print('========== SONUÇLAR ==========')
print(f'HAM GÖRÜNTÜ     → PSNR: {np.mean(psnr_raw_listesi):.2f} dB | SSIM: {np.mean(ssim_raw_listesi):.4f}')
print(f'İYİLEŞTİRİLMİŞ  → PSNR: {np.mean(psnr_iyi_listesi):.2f} dB | SSIM: {np.mean(ssim_iyi_listesi):.4f}')
fark_psnr = np.mean(psnr_iyi_listesi) - np.mean(psnr_raw_listesi)
fark_ssim = np.mean(ssim_iyi_listesi) - np.mean(ssim_raw_listesi)
print(f'FARK            → PSNR: {fark_psnr:+.2f} dB | SSIM: {fark_ssim:+.4f}')
# Out:
# ========== SONUÇLAR ==========
# HAM GÖRÜNTÜ     → PSNR: 16.58 dB | SSIM: 0.7428
# İYİLEŞTİRİLMİŞ  → PSNR: 16.29 dB | SSIM: 0.6579
# FARK            → PSNR: -0.30 dB | SSIM: -0.0850

# %% [markdown]
# outscale=1 → "Büyütme, sadece iyileştir"
# → Model daha az değişiklik yapıyor
# → Görsel fark az
#
# outscale=4 → "4 kat büyüt"
# → Model çok daha fazla piksel dolduruyor
# → Bu sırada çok daha fazla iyileştirme yapıyor
# → Görsel fark belirgin!

# %% [markdown]
# PSNR yorumu: 16.58 → 16.29, çok küçük bir düşüş. Piksel seviyesinde model referanstan biraz uzaklaşmış ama fark minimal.SSIM yorumu: 0.7428 → 0.6579, bu daha ciddi. Yapısal benzerlik 0.085 düştü. Model görüntünün dokusunu, kenarlarını değiştirmiş — referansın beklediği yapıdan uzaklaşmış.Genel: Model görüntüyü işliyor ama sualtı renk bozulmasını düzeltmek yerine genel keskinleştirme yapıyor.

# %%
import cv2
import os

raw_klasor = '/content/drive/MyDrive/raw-890'
iyi_klasor = '/content/drive/MyDrive/iyilestirilmis-890'

dosyalar = [f for f in os.listdir(iyi_klasor)][:5]

for dosya in dosyalar:
    raw = cv2.imread(os.path.join(raw_klasor, dosya))
    iyi = cv2.imread(os.path.join(iyi_klasor, dosya))

    if raw is None or iyi is None:
        continue

    kat = iyi.shape[0] / raw.shape[0]
    print(f'{dosya}:')
    print(f'  RAW: {raw.shape[1]}x{raw.shape[0]}')
    print(f'  İYİ: {iyi.shape[1]}x{iyi.shape[0]}')
    print(f'  Büyütme: {kat:.1f}x')
    print()
# Out:
# 186_img_.png:
#   RAW boyut: (771, 1200, 3)
#   REF boyut: (771, 1200, 3)
#   İYİ boyut: (1542, 2400, 3)
# ---
# 160_img_.png:
#   RAW boyut: (1150, 800, 3)
#   REF boyut: (1150, 800, 3)
#   İYİ boyut: (2300, 1600, 3)
# ---
# 15704.png:
#   RAW boyut: (720, 1280, 3)
#   REF boyut: (720, 1280, 3)
#   İYİ boyut: (1440, 2560, 3)
# ---
# 192_img_.png:
#   RAW boyut: (480, 640, 3)
#   REF boyut: (480, 640, 3)
#   İYİ boyut: (960, 1280, 3)
# ---
# 157_img_.png:
#   RAW boyut: (480, 640, 3)
#   REF boyut: (480, 640, 3)
#   İYİ boyut: (960, 1280, 3)
# ---

# %%
import os

raw_klasor = '/content/drive/MyDrive/raw-890'
iyi_klasor = '/content/drive/MyDrive/iyilestirilmis-890'
ref_klasor = '/content/drive/MyDrive/reference-890-extracted/reference-890'

raw_dosyalar = set(os.listdir(raw_klasor))
iyi_dosyalar = set(os.listdir(iyi_klasor))
ref_dosyalar = set(os.listdir(ref_klasor))

# Üçünde de olan dosyalar
ortak = raw_dosyalar & iyi_dosyalar & ref_dosyalar
print(f'Üçünde de olan görüntü sayısı: {len(ortak)}')
print('Örnek:', list(ortak)[:5])
# Out:
# Üçünde de olan görüntü sayısı: 198
# Örnek: ['517_img_.png', '15426.png', '206_img_.png', '19_img_.png', '138_img_.png']
